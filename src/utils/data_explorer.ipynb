# %%
import pandas as pd

df = pd.read_parquet(
    r"c:\Users\dasab\Desktop\MASTER\TFM\data/raw/datos_aire/parquet_files/DatosAire2022.parquet"
)

# %%
df.head()
# Out:
#    provincia  municipio  estacion  magnitud  punto muestreo  anno  mes  dia  \
# 0          8        184         6        10  08184006_10_47  2022    3    3
# 1         43        103         1         8    43103001_8_8  2022    3    3
# 2         26         89         1        14   26089001_14_6  2022    3    3
# 3          7         26         1        10  07026001_10_49  2022    3    2
# 4          7         32         3         8    07032003_8_8  2022    3    3
#
#   h01  h02  ... h15   h16   h17   h18   h19 h20   h21   h22   h23   h24
# 0   8   12  ...   9     9    12    12    14  15    12    14    18    17
# 1   8    7  ...   8     8     7    10    17  14    11    18    10    11
# 2  17   21  ...  16    15    14    20    20  27    30    38    41    47
# 3   7  6,3  ...  16  16,8  20,5  26,1  15,2  25  21,9  20,8  14,1  15,7
# 4   3    3  ...   3     3     3     3   8,6  18  17,1  21,6  16,6     3
#
# [5 rows x 32 columns]
